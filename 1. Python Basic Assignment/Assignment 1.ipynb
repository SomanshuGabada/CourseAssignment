# %% [markdown]
# #### 1. In the below elements which of them are values or an expression?
# ```
# eg:- values can be integer or string and expressions will be mathematical operators.
#
# *
# &#39;hello&#39;
# -87.8
# -
# /
# +
# 6
# ```

# %% [markdown]
# **Values :**
# ```
# &#39;hello&#39;
# -87.8
# 6
# ```
# **expression :**
# ```
# *
# -
# /
# +
# ```

# %% [markdown]
# #### 2. What is the difference between string and variable?

# %% [markdown]
# >String is collection of characters eg. "hello","how","now"
#
# >Variable is an container that contains some value eg. a=122 , b="dwq13eds" , c=2.1212

# %% [markdown]
# #### 3. Describe three different data types.

# %% [markdown]
# >Integer : Integer Datatype is represented by int keyword and is used for numbers eg 1,2,43,65,31321 .
#
# >Float : Float Datatype is represented by float keyword and is used for decimal numbers eg. 32.4 , 232.412
#
# >Character : Character Datatype is represented by char keyword and is used for text/string format eg. "asds" , "wqw" ,"hello" .

# %% [markdown]
# #### 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# > Expressions are statement containing two or more numbers along with mathematical operation , expressions are used to solve basic calculations and math problems .

# %% [markdown]
# #### 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
#  > A statement is just a standalone unit of execution and doesn’t return anything , and expression is a combination of operators and operands that perform a funtion and returns a value .
#
# > eg : here spam = 10 is just an statement that assigns a value to variable spam but dosent return anything
#  and (a+b/2) is expression that calculates and returns a specific output value

# %% [markdown]
# #### 6. After running the following code, what does the variable bacon contain?
# bacon = 22
#
# bacon + 1

# %%
bacon = 22
print(bacon+1)
# Out:
# 23

# %% [markdown]
# #### 7. What should the values of the following two terms be?
# &#39;spam&#39; + &#39;spamspam&#39;
#
# &#39;spam&#39; * 3

# %%
"spam" + "spamspam"
# Out:
# 'spamspamspam'

# %%
"spam"*3
# Out:
# 'spamspamspam'

# %% [markdown]
# #### 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# According to rules of variable ,
# > Variables must start with an alphabet and not with any numeric or alphanumeric character
#
# >And here the variable eggs is suitable for naming according to rules , but 100 starts with a number , hence 100 is an invalid variable name

# %% [markdown]
# #### 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# > **int()** for integer
#
# > **float()** for floating point
#
# > **str()** for string

# %% [markdown]
# #### 10. Why does this expression cause an error? How can you fix it?
# &#39;I have eaten &#39; + 99 + &#39; burritos.&#39;

# %%
'I have eaten ' + "99" + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
